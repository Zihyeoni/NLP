# %% [markdown]
# # **06-01 머신 러닝이란 (What is Machine Learning?)**
#
# ---

# %% [markdown]
# 머신 러닝은 영상 처리, 번역기, 음성 인식, 스팸 메일 탐지 등 굉장히 다양한 분야에서 응용되고 있음.
#
# 이번 챕터에서는 머신 러닝의 개념과 선형 회귀, 로지스틱 회귀, 소프트맥스 회귀와 같은 기본적인 모델을 이해함

# %% [markdown]
# ## **1. 머신 러닝(Machine Learning)이 아닌 접근 방법의 한계**
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 위 예시는 실제 2017년 DGIST 딥 러닝 경진대회 문제. 사람에게는 너무나 쉬운 일이지만, 이 문제를 풀 수 있는 프로그램을 작성하는 것은 상당히 난해한 수준임
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 사진을 보는 각도, 조명, 타겟의 변형(고양이의 자세)에 따라 천차만별이라 사진으로부터 공통된 명확한 특징을 잡아내기 쉽지 않음. 사실, 해당 프로그램은 숫자를 정렬하는 것과 같은 명확한 알고리즘이 애초에 존재하지 않음
#
# 이미지 내의 경계선과 같은 것들을 찾아내 알고리즘화를 시도하고, 다른 이미지가 들어오면 전반적인 상태를 비교해 분류하려고 시도함. 하지만 결국 특징을 잡아내는 것에 한계 존재

# %% [markdown]
# ## **2. 머신 러닝 방식**
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 머신 러닝은 데이터가 주어지면, 기계가 스스로 데이터로부터 규칙성을 찾는 것에 집중함
#
# **훈련(training), 학습(learning)**: 주어진 데이터로부터 규칙성을 찾는 과정
#
# (기존 방식 문제점 해결) 규칙성을 발견하고나면, 그 후에 들어오는 새로운 데이터에 대해서 규칙성을 기준으로 정답을 찾아냄
